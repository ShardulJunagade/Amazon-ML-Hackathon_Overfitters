# %%
import torch
import os
import requests
import numpy as np
from PIL import Image
from io import BytesIO
import cv2
from concurrent.futures import ThreadPoolExecutor
import easyocr
import re
import torch.nn as nn
import pandas as pd

# %%
# Ensure EasyOCR uses GPU
reader = easyocr.Reader(['en'], gpu=True)
# Out:
# /nlsasfs/home/aipsc/myksingh/myvenv/include/.venv/lib/python3.10/site-packages/easyocr/detection.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(trained_model, map_location=device)))
# /nlsasfs/home/aipsc/myksingh/myvenv/include/.venv/lib/python3.10/site-packages/easyocr/recognition.py:182: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

# %%
entity_unit_map = {
    'width': ['centimetre', 'cm', 'foot', 'ft', 'inch', 'in', 'metre', 'm', 'millimetre', 'mm', 'yard', 'yd'],
    'depth': ['centimetre', 'cm', 'foot', 'ft', 'inch', 'in', 'metre', 'm', 'millimetre', 'mm', 'yard', 'yd'],
    'height': ['centimetre', 'cm', 'foot', 'ft', 'inch', 'in', 'metre', 'm', 'millimetre', 'mm', 'yard', 'yd'],
    'item_weight': ['gram', 'g', 'kilogram', 'kg', 'microgram', 'µg', 'milligram', 'mg', 'ounce', 'oz', 'pound', 'lb', 'ton'],
    'maximum_weight_recommendation': ['gram', 'g', 'kilogram', 'kg', 'microgram', 'µg', 'milligram', 'mg', 'ounce', 'oz', 'pound', 'lb', 'ton', 't'],
    'voltage': ['kilovolt', 'kV', 'millivolt', 'mV', 'volt', 'V'],
    'wattage': ['kilowatt', 'kW', 'watt', 'W'],
    'item_volume': ['centilitre', 'cL', 'cubic foot', 'ft³', 'cubic inch', 'in³', 'cup', 'cup', 'decilitre', 'dL', 'fluid ounce', 'fl oz', 'gallon', 'gal', 'imperial gallon', 'imp gal', 'litre', 'L', 'microlitre', 'µL', 'millilitre', 'mL', 'pint', 'pt', 'quart', 'qt']
}

# %%
# ImageDataGenerator class as is
class ImageDataGenerator:
    def __init__(self, batch_size, image_links, image_shape=None):
        self.batch_size = batch_size
        self.image_links = image_links
        self.image_shape = image_shape

    def __len__(self):
        return len(self.image_links) // self.batch_size

    def __getitem__(self, idx):
        batch_links = self.image_links[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch = []
        for link in batch_links:
            try:
                response = requests.get(link)
                response.raise_for_status()  # Raise an exception for HTTP errors
                image = Image.open(BytesIO(response.content))
                grayscale_image = image.convert('L')
                image_array = np.array(grayscale_image)
                image_array = cv2.resize(image_array, self.image_shape)

                batch.append(torch.tensor(image_array).float())  # Add channel dimension
            except Exception as e:
                print(f"Error loading image from {link}: {e}")

        return torch.stack(batch)

# %%
# Preprocessing function
def preprocess_image(image_tensor):
    image_np = image_tensor.cpu().numpy().astype(np.uint8)
    denoised = cv2.medianBlur(image_np, 3)
    _, binary = cv2.threshold(denoised, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    binary_tensor = torch.tensor(binary).unsqueeze(0).float()  # Add channel
    return binary_tensor

# # OCR functions
# def apply_ocr(image_tensor):
#     config = '--oem 1 --psm 6'
#     image_np = image_tensor.squeeze(0).cpu().numpy().astype(np.uint8)
#     return pytesseract.image_to_string(image_np, config=config)

def easyocr_ocr(image_tensor):
    image_np = image_tensor.squeeze(0).cpu().numpy().astype(np.uint8)
    result = reader.readtext(image_np, detail=0)
    return " ".join(result)

# Entity extraction
def extract_value_and_unit_for_entity(text, entity):
    relevant_units = entity_unit_map[entity]
    pattern = r'(\d+(\.\d+)?)\s*(\w+)'
    matches = re.findall(pattern, text)
    results = [f"{match[0]} {match[2]}" for match in matches if match[2].lower() in relevant_units]
    return results

def ocr_pipeline(image_tensor, entity_name):
    preprocessed_image = preprocess_image(image_tensor)
    easyocr_result = easyocr_ocr(preprocessed_image)
    extracted_values = extract_value_and_unit_for_entity(easyocr_result, entity_name)
    if extracted_values:
        return extracted_values[0]

# %%
# Load train and test data
train_df = pd.read_csv('dataset/train.csv')
test_df = pd.read_csv("dataset/test.csv")


train_image_links = train_df['image_link'].tolist()
test_image_links = test_df['image_link'].tolist()

# %%
image_shape = (1024, 1024)
batch_size = 16

# train_generator = ImageDataGenerator(batch_size, train_image_links, image_shape)
test_generator = ImageDataGenerator(batch_size, test_image_links, image_shape)

# %%
batch_1 = test_generator.__getitem__(1)
batch_1[0].shape
# Out:
# torch.Size([1024, 1024])

# %%
# Parallel processing across 8 GPUs
def process_images_on_gpus(images, entity_names, num_gpus=7):
    # Split images into chunks for each GPU
    images_per_gpu = torch.chunk(images, num_gpus)
    entity_names_per_gpu = np.array_split(entity_names, num_gpus)
    
    # Assign to GPUs
    device = torch.device('cuda')
    results = []

    # Use torch DataParallel to run parallel across GPUs
    def process_on_single_gpu(images, entities, gpu_id):
        # print(gpu_id+1)
        images = images.cuda(gpu_id)
        gpu_results = []
        # print("Images:", images)
        # print(len(images))
        for i, image in enumerate(images):
            # print(i)
            # print(images[i])
            result = ocr_pipeline(image, entities[i])
            gpu_results.append(result)
        return gpu_results

    with ThreadPoolExecutor(max_workers=num_gpus) as executor:
        futures = [executor.submit(process_on_single_gpu, images_per_gpu[gpu_id], entity_names_per_gpu[gpu_id], gpu_id)
                   for gpu_id in range(num_gpus)]
        
        # Gather results
        for future in futures:
            results.extend(future.result())

    return results

# Run the processing loop
counter = 0
final=[]
for batch_images in test_generator:
    entity_names = test_df["entity_name"].values[counter: counter + len(batch_images)]
    
    # Process batch images on 8 GPUs
    results = process_images_on_gpus(batch_images, entity_names, num_gpus=8)
    final.extend(results)
    
    # Output results
    print(f"Batch {counter} processed, results: {results}")
    counter += len(batch_images)
# Out:
# Batch 0 processed, results: [None, None, None, None, None, None, None, None, '40 cm', '40 cm', None, None, None, None, None, None]
# Batch 16 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 32 processed, results: ['5.8 In', '5.8 In', '5.8 In', None, None, None, None, None, None, None, None, None, '12.5 m', '8 in', '8 in', '8 in']
# Batch 48 processed, results: [None, None, None, None, None, None, None, '7 cm', None, '54 m', '54 m', None, None, None, None, None]
# Batch 64 processed, results: [None, None, None, None, None, None, None, '23 cm', '23 cm', '23 cm', None, None, '4.7 in', '4.7 in', None, None]
# Batch 80 processed, results: [None, None, '11.1 lb', None, '39 in', '39 in', '39 in', None, None, None, '60 cm', '00 LB', None, None, None, '14 cm']
# /nlsasfs/home/aipsc/myksingh/myvenv/include/.venv/lib/python3.10/site-packages/torch/nn/modules/rnn.py:917: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ../aten/src/ATen/native/cudnn/RNN.cpp:1424.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# Batch 96 processed, results: ['14 cm', None, '5 cm', '14.9 in', None, None, None, '90 cm', '40 cm', '20 cm', '20 cm', None, None, '30 cm', None, None]
# Batch 112 processed, results: [None, None, None, None, None, None, '3.9 in', '3.9 in', None, None, None, None, None, None, None, '129 cm']
# Batch 128 processed, results: [None, None, '40 cm', '25.6 in', '25.6 in', '25.6 in', None, '0 cm', '0 cm', None, '29.95 cm', '10 mm', '10 mm', '3 cm', '02 in', '02 in']
# Batch 144 processed, results: ['90 cm', '90 cm', '90 cm', None, None, None, None, '7495 m', '7.86 in', '7.86 in', '5 cm', '5 cm', '35 mm', None, None, None]
# Batch 160 processed, results: ['13 cm', None, '82 cm', None, None, None, None, '6 kG', None, None, None, None, None, '7.8 In', '7.8 In', None]
# Batch 176 processed, results: [None, '0.79 inch', None, '5.9 in', '5.9 in', None, '24 cm', None, None, None, '7.19 cm', '7.19 cm', '2.7 in', '2.7 in', None, '61 cm']
# Batch 192 processed, results: ['61 cm', None, '20 cm', '27.6 cm', '27.6 cm', None, None, None, '37.5 cm', '37.5 cm', '37.5 cm', '10 in', '10 in', None, None, '67 m']
# Batch 208 processed, results: [None, None, '7 mm', None, '28 cm', None, None, None, None, None, None, None, '20.6 cm', '20.6 cm', '4191 cm', None]
# Batch 224 processed, results: ['90 cm', '90 cm', '26 cm', None, None, None, None, '60 cm', None, None, None, None, '35 cm', '183 cm', '183 cm', '60 cm']
# Batch 240 processed, results: ['60 cm', '35 Cm', '7 cm', '7 cm', '4 in', '151 cm', '151 cm', '78 cm', None, '2.32 in', '2.32 in', None, None, None, None, '16 cm']
# Batch 256 processed, results: ['16 cm', '16 cm', None, None, None, None, '80 cm', None, None, '2.55 in', '2.55 in', '11.6 in', '20 cm', '20 cm', '2.75 in', '2.75 in']
# Batch 272 processed, results: ['2.75 in', None, '1.5 in', '1.5 in', None, None, None, '1.9 in', '1.9 in', '109 G', '5.8 In', '5.8 In', None, '11 cm', '68 cm', None]
# Batch 288 processed, results: [None, None, None, '39 cm', '39 cm', '120 kg', '4.4 in', '4.4 in', None, None, None, None, None, None, None, None]
# Batch 304 processed, results: [None, None, None, None, None, '0.9 in', '0.9 in', '5 cm', None, None, '21 cm', '21 cm', '21 cm', '2 CM', '2 CM', None]
# Batch 320 processed, results: ['2.95 in', '2.95 in', '1 m', None, None, '1 in', '1 in', '7 CM', '7 CM', '7 CM', None, None, '40 cm', '40 cm', None, None]
# Batch 336 processed, results: [None, '0.7 in', '0.7 in', None, None, '11 g', '25 cm', '25 cm', '25 cm', '6 m', None, None, None, None, '2.8 inch', '2.8 inch']
# Batch 352 processed, results: [None, None, None, '95 inch', '95 inch', '5.0 in', '5.0 in', None, '0.59 in', '0.59 in', None, None, '7 m', '35 cm', '35 cm', '35 cm']
# Batch 368 processed, results: [None, '60 cm', '5 cm', '5 cm', None, '4.0 cm', '4.0 cm', '57 cm', '3 kg', None, None, '4.7 In', '4.7 In', '4.7 In', '60 cm', None]
# Batch 384 processed, results: [None, None, None, None, None, None, None, '100 cm', '100 cm', None, None, None, None, None, None, None]
# Batch 400 processed, results: [None, None, None, '120 cm', '7.9 cm', '7.9 cm', None, None, None, None, None, None, '10 m', '135 mm', None, None]
# Batch 416 processed, results: [None, None, '2.2 In', '2.2 In', None, None, None, '27 in', '27 in', '27 in', None, '11 cm', '1.3 in', '1.3 in', '300 cm', '63 cm']
# Batch 432 processed, results: ['3.9 inch', '3.9 inch', '3.9 m', '3.9 m', None, None, None, '144 mm', '144 mm', None, None, None, None, None, None, None]
# Batch 448 processed, results: [None, '2 cm', '43 cM', None, '88 cm', '120 cm', '15.2 cm', '3.14 in', '3.14 in', '6.29 in', '6.29 in', None, None, '60 cm', '60 cm', '60 cm']
# Batch 464 processed, results: [None, None, None, None, None, '9 in', '9 in', None, None, None, '1 cm', None, None, None, None, None]
# Batch 480 processed, results: [None, None, None, '57 cm', None, None, None, '5.9 in', '5.9 in', '5.9 in', '80 cm', '80 cm', '12 mm', '12 mm', '12 mm', None]
# Batch 496 processed, results: ['6.37 in', '6.37 in', '25 m', '25 m', '4.8 cm', None, '12 in', '12 in', None, None, None, None, None, None, None, None]
# Batch 512 processed, results: [None, None, None, None, '30 cm', '30 cm', '20 Mm', None, '39.3 in', '39.3 in', '6 m', '67 cm', '3.5 in', '3.5 in', '3.5 in', '7.07 in']
# Batch 528 processed, results: ['5.1 in', '5.1 in', '5.5 in', '5.5 in', None, None, '6 cm', None, None, '115.6 cm', None, '594 mm', None, '29.7 cm', '3.5 in', '3.5 in']
# Batch 544 processed, results: [None, '60.96 cm', '60.96 cm', '60.96 cm', None, None, None, '9.8 in', '9.8 in', None, '4 in', '4 in', None, None, '2.3 in', '25 kg']
# Batch 560 processed, results: [None, None, '15.72 in', '15.72 in', None, None, '3 kg', None, None, None, None, None, None, None, None, None]
# Batch 576 processed, results: [None, '7.88 In', '7.88 In', '60 CM', '60 CM', None, None, None, None, None, None, None, None, None, None, None]
# Batch 592 processed, results: ['60 cm', '170 cm', '170 cm', '5.9 in', '5.9 in', None, None, None, None, None, None, None, '0.9 in', '0.9 in', '0.9 in', None]
# Batch 608 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '7.8 in', '7.8 in']
# Batch 624 processed, results: ['8.4 in', '8.4 in', None, '8 cm', '8 cm', None, None, None, None, None, None, None, '30 cm', None, None, None]
# Batch 640 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 656 processed, results: [None, None, '80 cm', '44 CM', '44 CM', '13 CM', '26 cm', '26 cm', '26 cm', None, None, '7 cm', '7 cm', None, None, None]
# Batch 672 processed, results: [None, '8 In', '8 In', '10 cm', '10 cm', None, None, '78 in', '151 cm', '151 cm', '3.2 cm', '3.2 cm', None, None, None, None]
# Batch 688 processed, results: ['11 in', None, None, '14 mm', None, None, None, None, None, None, None, None, None, None, '9 cm', '9 cm']
# Batch 704 processed, results: ['9 cm', '7.87 in', '7.87 in', '80 cm', None, None, '80 cm', None, None, None, None, None, '88 cm', '17 in', '17 in', None]
# Batch 720 processed, results: ['11.8 in', '11.8 in', None, None, None, None, None, None, None, None, None, '6 m', '6 m', None, None, None]
# Batch 736 processed, results: [None, '8 mm', '8 mm', None, None, '3.5 in', '3.5 in', None, None, None, None, '35 m', '35 m', '27.9 cm', '27.9 cm', None]
# Batch 752 processed, results: [None, '5.9 in', '5.9 in', '0.7 in', '0.7 in', None, None, None, None, None, None, '1 cm', None, None, '2.75 in', '2.75 in']
# Batch 768 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '162 mm', '162 mm', None]
# Batch 784 processed, results: [None, None, None, None, '3.8 in', '3.8 in', '3.8 in', '5.1 in', '5.1 in', '9 in', '9 in', None, '12 cm', '12 cm', '12 cm', None]
# Batch 800 processed, results: [None, None, None, '26 In', '26 In', '26 In', None, '13 cm', None, None, None, None, None, None, None, None]
# Batch 816 processed, results: [None, None, None, '6 m', '6 m', '6 m', None, None, None, None, None, None, None, None, None, '8 CM']
# Batch 832 processed, results: [None, None, None, None, None, None, None, '29.5 in', '29.5 in', None, None, None, None, None, None, None]
# Batch 848 processed, results: [None, None, None, None, '4.625 in', '7 cm', '7 cm', '40 cm', '40 cm', None, None, None, '0 cm', None, '23 cm', '23 cm']
# Batch 864 processed, results: ['23 cm', None, None, None, None, '10.8 CM', '10.8 CM', None, '120 cm', '120 cm', None, '16 m', None, None, '60 cm', '9 in']
# Batch 880 processed, results: [None, None, '1.3 in', '1.3 in', None, None, None, None, None, '120 cm', '120 cm', '120 cm', '33 inch', '33 inch', None, None]
# Batch 896 processed, results: [None, '84 cm', None, None, None, '6 cm', '6 cm', None, '167 cm', '167 cm', '41 in', '41 in', '41 in', '8 cm', '60 cm', None]
# Batch 912 processed, results: [None, None, None, '12.9 in', '12.9 in', None, None, None, None, '5 cm', '5 cm', None, None, '120 cm', None, None]
# Batch 928 processed, results: [None, None, None, None, None, None, None, None, '30 cm', '30 cm', None, None, None, None, None, '7.8 in']
# Batch 944 processed, results: ['3 in', None, None, '21 kg', '0.98 in', '0.98 in', '3.9 in', '3.9 in', None, None, '120 cm', '120 cm', '37 mm', '37 mm', None, None]
# Batch 960 processed, results: ['27.5 cm', '27.5 cm', '28 cm', '28 cm', '28 cm', '2.75 in', '2.75 in', None, None, '1.37 in', None, None, '3.9 in', '3.9 in', '3.9 in', None]
# Batch 976 processed, results: ['8 in', '8 in', None, None, None, '2.7 in', '2.7 in', None, '2 cm', None, '38.5 cm', '18 cm', '18 cm', '11 in', None, '13 cm']
# Batch 992 processed, results: ['13 cm', '13 cm', None, None, None, None, None, None, None, '16 LB', '3.74 in', '3.74 in', None, None, None, None]
# Batch 1008 processed, results: [None, None, None, None, None, None, None, None, None, None, None, '72.01 cm', None, None, '148 mm', '148 mm']
# Batch 1024 processed, results: ['05 m', None, None, None, None, '1.77 in', '1.77 in', '96 cm', None, None, None, None, None, None, None, None]
# Batch 1040 processed, results: ['3 in', None, '9 in', '9 in', '111 M', None, None, None, None, None, None, '9 CM', None, None, None, '6 cm']
# Batch 1056 processed, results: [None, None, None, None, None, None, None, None, None, None, '44 cm', '44 cm', None, '4.5 In', '4.5 In', '4.5 In']
# Batch 1072 processed, results: ['7 in', '7 in', None, None, '70 cm', None, None, None, None, None, None, '147 m', '2.8 in', '2.8 in', '3.93 in', '3.93 in']
# Batch 1088 processed, results: ['3.93 in', None, '7.9 In', '7.9 In', '6 mm', None, '9 cm', '9 cm', '9 cm', '37.4 in', None, '28 g', None, None, None, None]
# Batch 1104 processed, results: [None, None, '2.63 in', '2.63 in', None, None, None, '180 cm', '45 cm', None, '24 cm', '6.4 in', '6.4 in', None, None, None]
# Batch 1120 processed, results: ['4.7 in', '4.7 in', '80 cm', None, '107 cm', '5 cm', None, None, '60 cm', None, None, None, '47 cm', '47 cm', '47 cm', None]
# Batch 1136 processed, results: ['8 cm', '8 cm', '14 cm', '14 cm', '7 m', '17 cm', '17 cm', '2.75 in', '2.75 in', None, None, None, None, None, None, None]
# Batch 1152 processed, results: ['45 cm', '45 cm', None, None, '120 cm', None, None, None, '76 cm', '76 cm', '76 cm', None, None, None, '6 in', '6 in']
# Batch 1168 processed, results: ['6 in', None, '3.9 in', '3.9 in', '25.5 cm', '25.5 cm', None, None, None, '110 cm', '10.62 in', '10.62 in', None, None, None, '8 cm']
# Batch 1184 processed, results: [None, None, '15 in', '15 in', None, None, None, None, '180 cm', '180 cm', '1 M', '1 M', '3.14 in', '3.14 in', '3.14 in', '20 m']
# Batch 1200 processed, results: ['20 m', None, '90 cm', None, '5 cm', '5 cm', '5 cm', '5 cm', '22 in', '22 in', None, None, None, None, '14.5 Oz', '60 cm']
# Batch 1216 processed, results: ['60 cm', '115 gram', None, '3.93 in', '3.93 in', '19 cm', '19 cm', '0.6 KG', None, None, None, None, None, None, '18 in', '18 in']
# Batch 1232 processed, results: [None, None, '20 m', None, '42 cm', '42 cm', None, '28 cm', None, None, None, None, None, None, None, None]
# Batch 1248 processed, results: ['5.7 in', '5.7 in', None, '12 cm', '12 cm', '203 g', None, None, '16 in', '13 CM', '13 CM', None, '2.4 in', '2.4 in', '68 cm', None]
# Batch 1264 processed, results: [None, None, '80 cm', '80 cm', '177.98 cm', '177.98 cm', None, None, None, None, '150 mm', '150 mm', '150 mm', None, None, None]
# Batch 1280 processed, results: ['1 cm', '34.22 Oz', None, None, None, None, None, None, None, None, None, '33 cm', '33 cm', None, '9.6 cm', '18 m']
# Batch 1296 processed, results: ['10.5 in', '10.5 in', None, None, '60 cm', '60 cm', None, None, None, None, None, None, None, None, None, None]
# Batch 1312 processed, results: [None, None, '15 in', '3.3 in', '3.3 in', '3.3 in', None, None, None, '235 cM', '235 cM', None, '9.2 in', '9.2 in', None, None]
# Batch 1328 processed, results: [None, '2 cm', None, None, None, None, None, '5.98 In', '5.98 In', '60 cm', '60 cm', None, None, None, None, '6.5 cm']
# Batch 1344 processed, results: ['12 In', '12 In', None, None, None, None, None, None, None, None, '1.77 in', '1.77 in', '5 CM', '5 CM', '5 CM', None]
# Batch 1360 processed, results: ['145 mm', '145 mm', '8 mm', None, '30 In', '30 In', '30 In', None, None, None, None, None, '97 in', '50 cm', '50 cm', '50 cm']
# Batch 1376 processed, results: [None, '244 cm', '244 cm', None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 1392 processed, results: [None, '100 cm', '100 cm', None, '21 cm', '21 cm', None, '48.01 cm', '1.8 kg', '9.8 in', '9.8 in', None, '66 cm', None, None, None]
# Batch 1408 processed, results: ['13 cm', '13 cm', None, None, None, None, None, '74 cm', None, '60 CM', '60 CM', '50 cm', '50 cm', '850 g', '850 g', '0.74 m']
# Batch 1424 processed, results: [None, None, None, '4 cm', '4 cm', None, None, None, '140 cm', '140 cm', None, None, None, None, None, None]
# Batch 1440 processed, results: [None, '9 cm', '9 cm', '330 mm', '5 kg', None, None, None, None, '33 cm', None, None, None, None, None, '50 Inch']
# Batch 1456 processed, results: ['50 Inch', '50 Inch', None, None, None, '7.1 in', '7.1 in', '2 cm', None, None, '3 in', None, None, '33 cm', '33 cm', None]
# Batch 1472 processed, results: [None, '66 cm', '30 cm', '30 cm', None, None, None, None, None, '57 mm', '57 mm', '57 mm', '78 cm', '78 cm', '10 kg', None]
# Batch 1488 processed, results: [None, '205 mm', '205 mm', '157 cm', None, None, None, None, '5 Inch', None, '600 mg', '2.1 in', '2 in', '2 in', '90 cm', None]
# Batch 1504 processed, results: [None, None, '218 g', '0.8 in', '9.5 cm', '9.5 cm', None, None, None, '264 mm', None, None, None, '10.22 in', '10.22 in', '2 cm']
# Batch 1520 processed, results: ['82.5 cm', None, None, '18 cm', '18 cm', None, None, None, None, None, None, None, None, None, None, None]
# Batch 1536 processed, results: [None, '4.7 in', '4.7 in', None, None, None, None, None, '0 cm', None, None, None, None, None, None, '94 in']
# Batch 1552 processed, results: [None, None, None, None, None, '8.3 in', '8.3 in', '8.3 in', None, '150 kg', '80 cm', '9.8 cm', '9.8 cm', None, '2.5 in', '2.5 in']
# Batch 1568 processed, results: ['2.5 in', '43 cm', '24.84 Cm', '1.6 kg', None, None, '27.2 g', None, None, None, None, None, None, None, '450 watt', '35 cm']
# Batch 1584 processed, results: ['35 cm', '35 cm', '25.8 mm', '25.8 mm', '5.7 in', '5.7 in', '5.7 in', '8 inch', '107 cm', '107 cm', '107 cm', None, None, None, '166 cm', '166 cm']
# Batch 1600 processed, results: ['11.8 inch', '11.8 inch', '11.8 inch', '200 mm', None, '250 mm', '45 cm', '3.25 in', '3.25 in', '3.25 in', '76 cm', '1.9 in', '3.9 in', '3.9 in', None, '8.06 in']
# Batch 1616 processed, results: ['8.06 in', None, None, None, '52 g', None, None, None, None, None, None, None, None, None, None, None]
# Batch 1632 processed, results: [None, None, None, '7.87 in', '7.87 in', None, None, None, '5 cm', '5 cm', None, None, None, None, '150 cm', '150 cm']
# Batch 1648 processed, results: ['150 cm', None, None, '100 cm', '100 cm', None, '2.32 in', '24 cm', '8 cm', None, None, None, None, None, None, '19 cm']
# Batch 1664 processed, results: [None, None, None, None, '1.54 in', None, None, None, None, None, '15.5 CM', None, None, None, None, '02 in']
# Batch 1680 processed, results: ['02 in', None, None, None, '60 mm', '10.8 CM', None, '16 mm', '16 mm', None, '50 kg', '30 kg', '5.9 in', '5.9 in', '5.9 in', '20.7 kg']
# Batch 1696 processed, results: ['20.7 kg', None, None, None, None, '28 Cm', '28 Cm', '28 Cm', '15.7 cm', '113 g', '60 mm', '60 mm', '22 cm', '3.6 m', '3.6 m', '33 cm']
# Batch 1712 processed, results: ['33 cm', '1.5 in', '1.5 in', None, None, None, None, '8 in', None, '7.5 cm', '7.5 cm', None, None, None, None, '250 kg']
# Batch 1728 processed, results: ['250 kg', None, None, None, None, None, None, '26 cm', '26 cm', None, None, '200 kg', '5.8 in', '5.8 in', None, None]
# Batch 1744 processed, results: [None, None, '42 mm', '42 mm', '42 mm', None, None, None, None, None, '17.8 cm', None, '19 mm', None, None, None]
# Batch 1760 processed, results: [None, '13.7 CM', '13.7 CM', None, '0 g', None, '25 mm', '16.3 kg', None, None, None, None, '13.09 in', '13.09 in', None, None]
# Batch 1776 processed, results: [None, '20 inch', None, None, '18 cm', '25 cm', '25 cm', '2 mm', '2 mm', None, '79 cm', None, None, '30 LB', '10 Oz', '37 cm']
# Batch 1792 processed, results: ['37 cm', None, None, '0.9 in', '0.9 in', '73 m', None, None, None, None, None, None, '11.59 in', None, None, '19 cm']
# Batch 1808 processed, results: ['19 cm', '16 cm', '16 cm', '16 cm', None, '7.87 in', '7.87 in', None, None, None, '7.8 in', '7.8 in', None, None, None, None]
# Batch 1824 processed, results: [None, '3.14 in', '3.14 in', '6.7 cm', None, '80.5 cm', None, None, None, None, None, None, None, '18.5 cm', None, '103 cm']
# Batch 1840 processed, results: [None, None, None, None, None, None, None, '7 cm', '2.7 in', '2.7 in', None, None, None, None, None, None]
# Batch 1856 processed, results: [None, None, None, '1.2 in', '1.2 in', None, '26 cm', None, None, None, None, '7.28 in', '200 mm', '2.0 in', '2.0 in', None]
# Batch 1872 processed, results: [None, None, None, None, None, None, None, '9 inch', '3 in', '3 in', '3 in', '5.12 inch', None, None, None, '19.5 cm']
# Batch 1888 processed, results: ['2.95 in', '2.95 in', '13.5 cM', None, None, None, None, None, '130 cm', None, '1.7 in', '1.7 in', '4.7 in', '4.7 in', '3.5 in', '3.5 in']
# Batch 1904 processed, results: [None, '2.4 in', '2.4 in', '9 inch', '9 inch', '49.2 in', '49.2 in', None, None, None, None, '8 in', None, None, None, '120 cm']
# Batch 1920 processed, results: ['1.77 in', '8 CM', '8 CM', None, None, '176 cm', None, '5.9 in', '5.9 in', '59 cm', '59 cm', None, '39 cm', None, None, None]
# Batch 1936 processed, results: [None, None, None, None, '35 CM', '35 CM', None, None, None, None, '2 cm', None, None, None, None, '1 m']
# Batch 1952 processed, results: [None, None, None, '49 inch', None, '8 cm', '8 cm', None, '9 Inch', '9 Inch', None, None, '140 mm', '140 mm', '4 in', None]
# Batch 1968 processed, results: ['6.5 CM', '8 cm', '8 cm', None, '28 mm', '28 mm', None, '61 MM', '61 MM', '14 cm', None, '25 cm', '25 cm', None, None, '27.45 kg']
# Batch 1984 processed, results: [None, None, '30 cm', None, None, None, '5 cm', '190 cm', None, '9.5 cm', None, None, None, '150 cm', None, None]
# Batch 2000 processed, results: [None, None, None, '5 cm', '35 cm', None, None, None, '1.38 INCH', '1.38 INCH', '108 cm', '108 cm', '108 cm', None, None, None]
# Batch 2016 processed, results: [None, None, None, None, '18 CM', '18 CM', '18 CM', None, None, None, '37 Cm', None, None, '15.00 cm', '15.00 cm', None]
# Batch 2032 processed, results: [None, None, None, '25 CM', None, '15 cm', '15 cm', None, None, None, '12.3 kg', '9 cm', '34.5 in', '34.5 in', '6 in', None]
# Batch 2048 processed, results: [None, None, '25 mm', '3 inch', '3 inch', '3 inch', '40 MM', None, '8 G', None, '98 cm', '133 mm', None, None, None, None]
# Batch 2064 processed, results: [None, None, None, None, '29 in', '9.8 m', None, None, '0.59 in', '0.59 in', None, None, None, None, None, None]
# Batch 2080 processed, results: [None, None, None, None, None, None, '2 In', '2 In', None, None, None, None, '3 in', '3 in', None, None]
# Batch 2096 processed, results: [None, None, None, '5 mm', '5 mm', None, None, '0.475 KG', None, None, None, None, '220 mm', '220 mm', None, None]
# Batch 2112 processed, results: ['25 kg', None, None, '94 mm', '94 mm', None, None, '16 cm', '16 cm', None, None, '2.16 in', '2.16 in', None, None, '38 cm']
# Batch 2128 processed, results: ['38 cm', '38 cm', None, None, None, None, '115 cm', None, None, '18.5 in', '18.5 in', '83 mm', None, None, None, None]
# Batch 2144 processed, results: [None, '20.6 cm', '5 cm', '9 in', None, None, None, None, '55.1 in', '55.1 in', '38 CM', None, '4.6 in', None, None, None]
# Batch 2160 processed, results: ['1.57 in', '1.57 in', '75 cm', None, None, None, '29.5 cm', '10 cm', '122 cm', '6 cm', '6 cm', '6 M', None, None, None, '21.3 cm']
# Batch 2176 processed, results: ['21.3 cm', '21.3 cm', '0 cm', '0 cm', '0 cm', None, None, None, '8 CM', None, None, None, None, None, None, '18 cm']
# Batch 2192 processed, results: ['18 cm', None, '0 cm', '0 cm', '7 CM', '7 CM', '3 m', '3 m', None, '93 cm', None, None, None, None, '2 CM', None]
# Batch 2208 processed, results: [None, '38 in', '38 in', None, '15 LB', '624 cm', '624 cm', None, None, None, None, None, None, None, '14.17 in', None]
# Batch 2224 processed, results: [None, None, '163 Cm', None, None, None, None, None, '5 cm', None, '2.1 FT', '2.1 FT', None, None, None, None]
# Batch 2240 processed, results: [None, None, None, '1.8 in', '1.8 in', '1.8 in', '6 CM', '7 inch', '7 inch', None, None, '10.5 cm', None, '14.3 cm', '5.03 in', '5.03 in']
# Batch 2256 processed, results: [None, None, None, None, None, None, None, None, None, '3.54 in', None, None, None, '8.8 kg', None, None]
# Batch 2272 processed, results: [None, None, None, '400 mm', '400 mm', None, '140 cm', None, '120 cm', '120 cm', None, None, None, '75 cm', '75 cm', None]
# Batch 2288 processed, results: [None, '28.5 CM', '28.5 CM', None, None, None, None, None, None, None, None, None, '80 cm', '80 cm', None, None]
# Batch 2304 processed, results: [None, None, None, None, '100 cm', '174 cm', '174 cm', None, None, None, '29.87 in', None, '4 IN', '4 IN', '10 Oz', None]
# Batch 2320 processed, results: [None, None, None, None, '25.5 cm', None, None, '45 cm', '45 cm', None, '350 lb', None, None, '11.28 mm', '11.28 mm', '13.6 inch']
# Batch 2336 processed, results: ['0037 G', '8 cm', '8 cm', None, None, '3.1 in', '3.1 in', None, None, None, '8 In', None, None, '6.5 cm', '6.5 cm', '088 mm']
# Batch 2352 processed, results: ['46.85 in', '17 cm', '117 cm', '117 cm', None, '35 MM', None, None, None, None, '7 in', '58 CM', '4.7 in', '4.7 in', None, None]
# Batch 2368 processed, results: [None, None, '360 mm', '20 cm', '20 cm', None, '150 kg', '6.1 cm', '92.2 cm', '0 G', '1.8 LB', None, '23 cm', '23 cm', None, None]
# Batch 2384 processed, results: [None, '20 CM', None, '9.5 cm', '43 cm', '43 cm', '43 cm', '31 in', '31 in', None, None, None, None, '97 cm', None, None]
# Batch 2400 processed, results: [None, '260 cm', '2.76 inch', '2.76 inch', '29 cm', '29 cm', None, '12 in', '12 in', '160 mM', '160 mM', '2.1 KG', None, '12 CM', '19 cm', '19 cm']
# Batch 2416 processed, results: ['3 in', '3 in', '3 in', None, '18.5 In', None, None, None, '120 cm', '120 cm', '120 cm', None, None, '10 inch', None, None]
# Batch 2432 processed, results: [None, '2.95 inch', '2.95 inch', None, None, '1 inch', '120 kg', None, None, None, '12.59 in', '12.59 in', '84 in', '84 in', '84 in', None]
# Batch 2448 processed, results: [None, None, '2.20 in', '2.20 in', '60 cm', '180 cm', '4 inch', '4 inch', None, None, None, None, None, '90 cm', None, '21 cm']
# Batch 2464 processed, results: ['62 mm', None, None, None, '120 cm', '120 cm', '35 cm', '35 cm', '35 cm', '21 mm', '21 mm', None, None, None, '32 cm', None]
# Batch 2480 processed, results: ['2.4 in', '2.4 in', '29 cm', '29 cm', None, None, '6 in', None, '12 Volt', '3.93 in', '3.93 in', '3.93 in', '80 cm', None, None, None]
# Batch 2496 processed, results: [None, None, '8 cm', '8 cm', '11.75 inch', '11.75 inch', '11.75 inch', '130 mm', None, None, None, None, None, '15 cm', '15 cm', '15 cm']
# Batch 2512 processed, results: [None, '6 oz', None, '10 cm', '10 cm', None, None, None, '115 cm', None, None, '2 in', None, None, '48 cm', None]
# Batch 2528 processed, results: ['6 LB', '304.8 m', '304.8 m', '304.8 m', None, '4.72 in', '96 mm', '96 mm', '7.5 CM', None, None, None, '41 m', '15.72 in', '15.72 in', '40 cm']
# Batch 2544 processed, results: ['40 cm', None, None, None, '4.7 in', '4.7 in', None, '75 mm', '75 mm', None, '11.8 in', None, None, None, '6 g', None]
# Batch 2560 processed, results: [None, None, '191 g', None, None, None, None, None, '4 cm', '4 cm', None, None, None, None, None, None]
# Batch 2576 processed, results: [None, None, None, None, None, None, None, '5 in', '5 in', '1.4 KG', '1.4 KG', '5.1 in', '5.1 in', '140 cm', None, '18 cm']
# Batch 2592 processed, results: ['18 cm', None, '35 mm', '20.3 cm', '20.3 cm', '20.3 cm', None, None, '7 g', None, None, None, None, None, None, None]
# Batch 2608 processed, results: [None, '12.59 in', '12.59 in', None, None, None, None, None, None, None, '30.5 cm', '59 CM', '48 cm', '5 inch', '5 inch', None]
# Batch 2624 processed, results: [None, None, None, None, None, None, None, '8 cm', '8 cm', None, None, None, '8.4 in', '8.4 in', '8.6 in', None]
# Batch 2640 processed, results: [None, None, '330 lb', '17 cm', '17 cm', '9.8 in', '9.8 in', '9.8 in', None, None, None, None, None, None, None, None]
# Batch 2656 processed, results: [None, '6.89 inch', '6.89 inch', None, None, '14 cm', '14 cm', None, None, '117 mm', '117 mm', None, '38.5 Cm', None, None, None]
# Batch 2672 processed, results: [None, None, None, '11.8 in', '11.8 in', None, '18 cm', '22.44 In', '22.44 In', None, None, None, None, None, None, None]
# Batch 2688 processed, results: ['7.5 cm', '7.5 cm', '7.5 cm', None, None, '26 cm', '26 cm', '6.10 in', '6.10 in', None, None, None, None, None, None, None]
# Batch 2704 processed, results: ['4.33 inch', None, '8.2 cm', '8.2 cm', None, None, None, None, '20 cm', '20 cm', None, '14.1 in', '14.1 in', '90 mm', '90 mm', '90 mm']
# Batch 2720 processed, results: [None, '1 in', '21 cm', '21 cm', None, '06 inch', '06 inch', None, None, None, None, None, None, None, None, None]
# Batch 2736 processed, results: ['13 cm', '13 cm', '13 cm', '63 cm', None, None, None, None, None, '225 cm', '225 cm', None, '5 CM', '5 CM', None, None]
# Batch 2752 processed, results: [None, '0.2 IN', None, '1570 Watt', None, '18.5 CM', '18.5 CM', None, None, '15.7 in', '15.7 in', '3.0 in', '3.0 in', None, None, '2.5 cm']
# Batch 2768 processed, results: ['2.5 cm', None, '0 kg', '101 mm', None, None, None, None, None, None, '21.5 Cm', '200 LB', '22 cm', '22 cm', '22 cm', None]
# Batch 2784 processed, results: [None, '18 m', '18 m', '18 m', '5.00 CM', None, None, '4.91 in', '4.52 in', '4.52 in', '12 cm', '25 G', '102 cm', None, None, '8 cm']
# Batch 2800 processed, results: ['8 cm', None, None, '8 CM', None, '175 mm', '27 CM', None, None, None, None, None, None, None, '4.52 in', None]
# Batch 2816 processed, results: [None, None, None, None, None, None, None, None, None, None, '14 cm', '7.8 cm', '7.8 cm', None, None, None]
# Batch 2832 processed, results: [None, None, '16 in', '16 in', None, None, '12 cm', None, None, None, None, '8 cm', '8 cm', '8 cm', '1 t', None]
# Batch 2848 processed, results: [None, None, None, '5.6 cm', None, None, '1.8 In', '1.8 In', '220 mm', '220 mm', None, None, None, None, None, None]
# Batch 2864 processed, results: ['120 cm', None, None, '4 cm', '4 cm', '8.46 in', '8.46 in', '65 g', '65 g', '79 inch', None, None, None, None, None, None]
# Batch 2880 processed, results: [None, '11.5 KG', '11 inch', '11 inch', None, None, None, None, None, None, None, None, None, '140 cm', None, '4.8 cm']
# Batch 2896 processed, results: ['4.8 cm', None, None, None, '9.9 cm', None, None, '127 cm', None, '2.2 in', '2.2 in', '57 CM', '57 CM', None, None, '6 cm']
# Batch 2912 processed, results: [None, None, None, None, '8.8 oz', '60 m', '4.1 in', '4.1 in', '4.1 in', '2.0 in', '2.0 in', '54 inch', '54 inch', '54 inch', None, None]
# Batch 2928 processed, results: [None, '8 in', '8 in', '10.3 mm', '7.87 in', '7.87 in', None, None, None, '2 in', '2 in', '2 in', '3.73 in', None, None, None]
# Batch 2944 processed, results: ['4 cm', '4 cm', None, '8 cm', '8 cm', None, None, None, None, None, None, '65 cm', None, None, '2.5 cm', '340 g']
# Batch 2960 processed, results: [None, '30 CM', None, '14 cm', '14 cm', None, None, '135 mm', '135 mm', '135 mm', None, '48 CM', '81 mm', None, None, None]
# Batch 2976 processed, results: [None, '10 LB', '0 LB', '38 CM', '410 g', None, None, None, None, None, '50 g', '80 mm', '8.6 CM', '8.6 CM', None, None]
# Batch 2992 processed, results: [None, None, None, '7 ft', '4.13 in', '4.13 in', '14 cm', '14 cm', '48 cm', '48 cm', None, None, '3 in', None, None, None]
# Batch 3008 processed, results: [None, None, None, None, None, None, None, None, None, '22 Cm', '22 Cm', None, '8 CM', '28 CM', None, None]
# Batch 3024 processed, results: [None, None, None, None, '454 g', None, None, None, '9.4 in', '9.4 in', None, None, None, None, None, None]
# Batch 3040 processed, results: [None, '8.27 in', '8.27 in', None, None, None, None, None, '2.1 kg', '42 inch', None, None, None, None, None, None]
# Batch 3056 processed, results: [None, None, None, '7 cm', None, '14 kg', None, None, None, None, None, None, None, None, None, '30 in']
# Batch 3072 processed, results: ['30 in', None, '6 cm', '11.2 in', '11.2 in', None, None, None, '17 MM', '17 MM', '120 mm', '4.33 in', '4.33 in', '2 cm', '2 cm', None]
# Batch 3088 processed, results: [None, None, '2.95 in', None, '6.3 in', '23 mm', None, '9.8 in', None, None, None, None, None, None, None, None]
# Batch 3104 processed, results: ['43 CM', '1.45 in', '1.45 in', '95 CM', '95 CM', '95 CM', None, None, None, None, None, None, None, None, '3 cm', '3 cm']
# Batch 3120 processed, results: [None, None, None, '6.7 in', '6.7 in', '15.75 inch', None, None, None, None, None, None, '1.5 cm', None, None, None]
# Batch 3136 processed, results: ['11.8 in', '11.8 in', None, None, '150 KG', None, None, None, None, None, None, None, None, None, None, None]
# Batch 3152 processed, results: ['8 cm', '8 cm', '1.6 in', '1.6 in', None, None, None, None, '2.4 inch', None, '120 LB', None, '4.6 inch', '4.6 inch', '50 cm', None]
# Batch 3168 processed, results: [None, None, None, None, None, None, None, None, None, None, None, '5.3 in', '5.3 in', None, None, None]
# Batch 3184 processed, results: [None, None, '12 cm', '12 cm', None, None, None, None, None, '330 lb', None, None, None, None, None, '2.36 inch']
# Batch 3200 processed, results: [None, None, None, None, None, None, '10 CM', '1 M', None, None, None, '15 Inch', None, None, None, None]
# Batch 3216 processed, results: [None, None, '42.4 cm', None, None, None, None, None, None, None, None, '8.7 in', None, '1.5 in', '31 cm', None]
# Batch 3232 processed, results: [None, None, None, '30 cm', '12 mm', '48 inch', None, None, None, None, '98 cm', None, '5 inch', '5 inch', None, None]
# Batch 3248 processed, results: [None, None, None, None, None, '30 cm', '47 cm', '47 cm', None, '15 cm', '44 LB', None, None, None, None, '10 cm']
# Batch 3264 processed, results: ['15 cm', '15 cm', '13.5 inch', '13.5 inch', None, None, None, '40.64 cm', '40.64 cm', None, '12 cm', '3.2 in', '3.2 in', '9 cm', '3 lB', None]
# Batch 3280 processed, results: [None, None, '7.27 in', '7.27 in', None, None, None, '10 cm', None, None, None, None, None, None, '5.8 CM', '5.8 CM']
# Batch 3296 processed, results: ['110 cm', None, '23.62 in', None, None, '1.5 in', None, '5.8 cm', None, '40 cm', '40 cm', None, None, '290 mm', '7.4 in', None]
# Batch 3312 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '24 kG', '1.18 inch', '1.18 inch', None]
# Batch 3328 processed, results: ['8 IN', '8 IN', None, None, None, '25 cm', '340 m', None, None, '25 LB', '40 cm', '40 cm', '8 cm', None, None, None]
# Batch 3344 processed, results: [None, None, None, '1.18 IN', '1.18 IN', '13 cm', '13 cm', None, None, None, None, '52 cm', None, '2.36 in', '2.36 in', '2.8 in']
# Batch 3360 processed, results: [None, None, None, None, None, '13 cm', None, '90 KG', None, None, '7 cm', None, None, '5.5 Cm', '52 mm', None]
# Batch 3376 processed, results: [None, None, '13.4 kg', '3 m', '3 m', '3 m', None, '0.79 in', '0.79 in', '0.79 in', '82 mm', '82 mm', '0195 mm', '5 T', None, None]
# Batch 3392 processed, results: [None, None, None, '6 cm', '6 cm', None, None, '11 cm', None, None, None, '8 M', '97.16 m', '18 Inch', None, None]
# Batch 3408 processed, results: [None, None, None, '15.7 m', None, '32 Oz', '6 m', '9.8 in', '9.8 in', None, None, '65 cm', '65 cm', None, None, '210 m']
# Batch 3424 processed, results: ['210 m', '00 mm', None, None, None, '4 m', '4 m', '6.5 in', '6.5 in', None, None, '7 In', None, None, '6.4 cm', '6.4 cm']
# Batch 3440 processed, results: [None, '2 cm', None, None, '3.6 inch', None, None, None, None, None, None, None, None, '3.1 CM', '3.1 CM', None]
# Batch 3456 processed, results: [None, '11.4 In', '11.4 In', None, None, None, None, None, None, None, None, None, None, None, '60 cm', '10 m']
# Batch 3472 processed, results: ['10 m', None, None, '12.7 cm', '12.7 cm', None, '6 cm', '6 cm', None, None, '5.3 cm', None, None, '84 Mm', '8.06 in', '8.06 in']
# Batch 3488 processed, results: ['117.5 cm', '117.5 cm', None, None, '12 cm', '12 cm', '4 m', '4 m', '4 m', '150 KG', '9.0 in', '9.0 in', None, '3.5 In', '3.5 In', '10.0 in']
# Batch 3504 processed, results: ['10.0 in', None, None, '27 cm', '220 cm', '15 cm', '15 cm', None, None, '2.48 in', None, None, None, '2.55 in', None, None]
# Batch 3520 processed, results: [None, '102 cm', '8.5 mm', None, None, None, None, '3 mm', None, None, None, '035 mm', '9 cm', None, '3.9 cm', None]
# Batch 3536 processed, results: [None, '19 cm', '19 cm', None, None, '72 cm', '72 cm', '72 cm', None, '255 kg', '13 in', '7 inch', '7 inch', '77 in', None, '8 g']
# Batch 3552 processed, results: [None, '7.86 in', '7.86 in', None, None, '3 cm', '5 cm', '5 cm', '46 in', None, None, None, None, None, None, '3.4 inch']
# Batch 3568 processed, results: [None, '35.04 in', '4.52 in', None, None, '103.5 cm', '103.5 cm', None, None, '11.8 cm', '11.8 cm', '11.8 cm', '8 LB', None, None, '2.36 in']
# Batch 3584 processed, results: ['7.5 cm', '7.5 cm', None, None, None, None, None, '2.36 in', '2.36 in', '34 cm', None, '5 cm', '35 Inch', None, None, '40.1 cm']
# Batch 3600 processed, results: [None, '90.03 mm', '90.03 mm', '90.03 mm', None, '47.24 in', '33 cm', '150 cm', '150 cm', '58 cm', '58 cm', '226.7 G', None, None, None, '425 mm']
# Batch 3616 processed, results: ['425 mm', '0 t', None, None, None, None, None, None, None, None, None, '6 cm', None, None, None, '1 t']
# Batch 3632 processed, results: [None, None, None, None, '40 cm', '40 cm', '11.8 INCH', '11.8 INCH', '11.8 INCH', '8 cm', None, None, None, '10.5 CM', '10.5 CM', None]
# Batch 3648 processed, results: [None, '13 KG', '16 OZ', None, None, None, None, None, None, '603 mm', '603 mm', '603 mm', None, None, None, '30 cm']
# Batch 3664 processed, results: ['30 cm', '22 cm', '25 mm', '10.8 cm', None, '5.91 in', '5.91 in', '5.91 in', '150 cm', '6 cm', '6 cm', '6.9 CM', None, '95 cm', None, None]
# Batch 3680 processed, results: [None, '7 cm', '7 cm', None, None, '170 mm', '170 mm', '180 cm', None, '12 cm', '12 cm', '12 cm', None, None, '150 CM', '6.5 CM']
# Batch 3696 processed, results: ['6.5 CM', '1 in', '1 in', None, None, '17 in', '17 in', None, None, None, None, None, None, None, None, None]
# Batch 3712 processed, results: [None, '9 CM', None, None, '2.3 in', '2.3 in', '8.6 in', '8.6 in', '8.6 in', '72 cm', None, None, None, '5.0 in', '5.0 in', None]
# Batch 3728 processed, results: ['25 mm', '25 mm', None, None, None, None, '80 in', '80 in', None, None, None, '464 mm', None, None, None, None]
# Batch 3744 processed, results: ['16 mm', '16 mm', None, None, '130 mm', '130 mm', '30 cm', '350 G', '80 cm', '195 m', '195 m', '55 cm', '55 cm', '92 cm', None, '5.89 in']
# Batch 3760 processed, results: ['5.89 in', '35 cm', '6.8 cm', '9 mm', '9 mm', None, None, None, None, None, None, None, '8.06 in', '8.06 in', None, None]
# Batch 3776 processed, results: ['36 cm', None, None, None, None, None, '5.2 inch', None, None, None, None, None, '11.8 in', '11.8 in', None, None]
# Batch 3792 processed, results: [None, '6 in', None, '40 cm', '8 cm', None, None, None, '3 mm', '3 mm', None, None, None, None, '41 cm', None]
# Batch 3808 processed, results: ['185 cm', '185 cm', '11.98 cm', '11.98 cm', '8.25 in', '43 cm', '43 cm', '43 cm', '5 CM', '5 CM', '5.9 INCH', None, None, None, None, None]
# Batch 3824 processed, results: [None, None, None, None, None, None, '75 KG', '31 cm', '31 cm', '75 IN', '75 IN', None, '1 in', '1 in', None, None]
# Batch 3840 processed, results: ['23 cm', '23 cm', None, None, None, '69.2 KG', None, None, '2.7 in', None, '47 cm', '47 cm', '10.4 in', '10.4 in', None, None]
# Batch 3856 processed, results: [None, None, '2.5 in', '2.5 in', None, '6.3 in', '6.3 in', None, '60 CM', '60 CM', '60 CM', None, None, '0.39 in', '0.39 in', None]
# Batch 3872 processed, results: [None, None, '34 g', '34 g', None, None, None, '152 cm', '152 cm', None, None, None, None, '14.75 cm', None, '8 mm']
# Batch 3888 processed, results: ['4.3 in', '4.3 in', None, None, None, '20.5 cm', '20.5 cm', '100.00 mm', '100.00 mm', '8.17 in', '27 cm', '27 cm', '2.37 kg', '6 m', '6 m', None]
# Batch 3904 processed, results: ['11.0 in', '11.0 in', '18 Oz', '17 mm', '250 KG', '250 KG', '7 in', '68 CM', '68 CM', None, None, None, '200 g', '32 cm', '32 cm', None]
# Batch 3920 processed, results: [None, None, None, None, '0.7 lb', '8.66 in', None, None, '13 cm', '13 cm', '8 cm', None, None, None, None, None]
# Batch 3936 processed, results: ['0 cm', None, None, None, None, None, None, None, None, '115 mm', '11 cm', '11 cm', None, '4.3 in', '6.48 in', '6.48 in']
# Batch 3952 processed, results: [None, '136 cm', None, None, '14 cm', '14 cm', None, '39 cm', '39 cm', None, None, None, None, None, None, None]
# Batch 3968 processed, results: ['5 t', None, '5 cm', None, None, None, None, None, None, '4 cm', '4 cm', None, None, '8 in', '7 CM', '7 CM']
# Batch 3984 processed, results: ['5 inch', '5 inch', '8 In', '8 In', None, None, None, None, None, '108 cm', '108 cm', '9.4 in', '9.4 in', None, None, None]
# Batch 4000 processed, results: ['2.28 inch', '2.28 inch', '133 CM', None, None, None, '25 inch', '25 inch', '13.8 cm', None, '076 m', '076 m', '130 mm', '130 mm', None, None]
# Batch 4016 processed, results: [None, '37 mm', '37 mm', None, '8.5 Inch', '8.5 Inch', '6.2 in', '6.2 in', '6.2 in', '8.0 in', '8.0 in', None, None, None, None, None]
# Batch 4032 processed, results: [None, None, None, None, None, '9 inch', '9 inch', '10 CM', '10 CM', None, '10.5 cm', '10.5 cm', None, '2.6 cm', '2.4 kg', '1 cm']
# Batch 4048 processed, results: ['1 cm', None, None, '3.1 in', '3.1 in', '5 cm', '15.5 cm', '15.5 cm', None, None, None, None, None, None, '23 m', None]
# Batch 4064 processed, results: ['30 cm', '30 cm', None, None, None, None, None, None, '72 mm', '72 mm', None, None, None, '13.7 cm', None, None]
# Batch 4080 processed, results: [None, None, None, '0 mm', '110 VOLT', '3.75 in', '3.75 in', None, None, None, None, None, '9.8 in', '11.8 in', '11.8 in', None]
# Batch 4096 processed, results: ['300 kg', None, '5.1 in', '5.1 in', '4.92 inch', '4.92 inch', '58 cm', '3.93 in', '3.93 in', None, None, None, None, None, None, None]
# Batch 4112 processed, results: ['3.9 In', '3.9 In', '3.9 In', None, None, '156 g', None, None, None, None, '3.94 inch', '3.54 in', '3.54 in', '5.91 In', '5.91 In', None]
# Batch 4128 processed, results: ['170 cm', None, None, None, '55 cm', None, '711 G', None, None, None, None, None, None, None, '1.4 kg', None]
# Batch 4144 processed, results: ['6 cm', '6 cm', None, None, None, None, None, '160 mm', '160 mm', None, None, None, None, None, None, '120 cm']
# Batch 4160 processed, results: [None, None, None, None, None, '10 cm', '10 cm', None, None, None, '11.9 in', '11.9 in', '7.4 in', '7.4 in', None, None]
# Batch 4176 processed, results: [None, '5 cm', '1.37 in', None, '3 in', '176 mm', '10 Oz', None, '35 mm', None, None, None, '5.89 in', '7.07 in', '7.07 in', None]
# Batch 4192 processed, results: [None, None, '16.5 cm', '16.5 cm', '16.54 in', '134 mm', '10 g', None, None, None, None, None, '8 inch', '9 mm', None, None]
# Batch 4208 processed, results: [None, '2 in', '2 in', '65 mm', '65 mm', '65 mm', None, '4.0 in', '4.0 in', '96 MM', '39 cm', '39 cm', '39 cm', None, '140 cm', '165 cm']
# Batch 4224 processed, results: ['165 cm', None, None, '7.8 INCH', '7.8 INCH', None, '0 kg', None, None, '11 cm', '11 cm', '7.1 in', None, '1 cm', '75 cm', None]
# Batch 4240 processed, results: ['2.67 in', '175 cm', None, None, None, None, None, None, None, '11 inch', '11 inch', '11 inch', '25 cm', '8.9 in', '8.9 in', '8.9 in']
# Batch 4256 processed, results: [None, None, None, None, None, None, '6.8 cm', '6.8 cm', '6.8 cm', '7.28 in', '7.28 in', '7.28 in', '40 cm', None, None, None]
# Batch 4272 processed, results: [None, None, '15385 m', '0.4 in', '0.4 in', None, None, None, '15.75 inch', '15.75 inch', '15.75 inch', None, '5 cm', None, None, None]
# Batch 4288 processed, results: ['10 cm', None, '5.5 LB', '0.5 in', '0.5 in', None, None, None, None, None, '7 in', None, None, '90 cm', '90 cm', None]
# Batch 4304 processed, results: ['19 cm', None, None, None, '5 cm', '3.625 In', None, '35 cm', '35 cm', None, '2.95 in', '2.95 in', None, None, None, None]
# Batch 4320 processed, results: [None, None, None, None, None, None, None, '9.8 ft', '9.8 ft', None, '2.8 cm', '2.8 cm', '2 KG', None, '20 LB', None]
# Batch 4336 processed, results: [None, None, None, None, None, '100 cm', '100 cm', None, None, '0 LB', '3.9 in', '8 cm', '8 cm', '270 cm', '270 cm', '11.8 in']
# Batch 4352 processed, results: ['11.8 in', '11.8 in', '55 cm', '55 cm', None, None, None, None, None, '2.75 inch', '2.75 inch', None, '4.5 m', '4.5 m', None, None]
# Batch 4368 processed, results: ['1 g', None, None, None, None, None, None, None, '95 mm', '24 inch', '24 inch', None, '1.7 in', '1.7 in', None, None]
# Batch 4384 processed, results: [None, '1 KG', None, None, '55 cm', '13 cm', '11.8 in', '11.8 in', None, None, '16 cm', None, None, None, '160 cm', '8 mm']
# Batch 4400 processed, results: ['8 mm', '2.87 in', '2.87 in', None, '12.3 kg', None, None, '19 cm', None, None, None, '6.1 in', '4.5 in', '5.78 in', '5.78 in', '67 mm']
# Batch 4416 processed, results: [None, None, None, None, '140 cm', None, '7 in', '7 in', None, None, '60 cm', '300 CM', None, None, '8.5 cm', None]
# Batch 4432 processed, results: [None, '6.2 cm', '137 cm', None, None, None, None, None, None, None, '30 cm', '30 cm', None, None, None, None]
# Batch 4448 processed, results: [None, None, None, None, '16 mm', '16 mm', '54 inch', '21.8 cm', '21.8 cm', None, None, None, None, None, '16 m', '16 m']
# Batch 4464 processed, results: ['16 m', None, None, '1 lb', '280 mm', None, None, '3.1 in', '3.1 in', '4.7 in', '4.7 in', None, None, None, None, None]
# Batch 4480 processed, results: [None, '5 cm', '5 cm', None, None, None, None, '1 in', '2.91 in', '2.91 in', None, None, '33.5 cm', '79 cm', '79 cm', None]
# Batch 4496 processed, results: [None, '40 cm', '40 cm', '8.5 in', '8.5 in', None, None, None, None, None, None, None, '9 cm', '9 cm', None, None]
# Batch 4512 processed, results: [None, None, None, None, None, None, '9 CM', '9 CM', '12.6 in', '12.6 in', '5 cm', '5 cm', None, None, '11 CM', None]
# Batch 4528 processed, results: ['1 G', '1 in', '1 in', None, None, '24 Cm', None, None, None, None, None, None, None, None, '86 in', None]
# Batch 4544 processed, results: ['22 CM', '22 CM', None, None, '5.1 in', '5.1 in', '5.1 in', None, None, None, None, None, None, None, None, '49 CM']
# Batch 4560 processed, results: ['49 CM', '70 mm', None, None, None, '13 cm', None, None, None, None, '75 mm', '75 mm', None, '16 cm', None, None]
# Batch 4576 processed, results: ['12 cm', '12 cm', '5.3 in', '5.3 in', '5.3 in', None, '1 cm', None, '3 cm', '3 cm', '5.9 in', '22.7 mm', '22.7 mm', '6.7 kg', '5 mm', '5 mm']
# Batch 4592 processed, results: ['5 mm', '151 cm', None, None, None, None, None, None, None, '35.4 inch', '35.4 inch', None, None, '2.75 Inch', '1.9 in', None]
# Batch 4608 processed, results: ['3.3 LB', None, None, None, '9.8 in', None, '60 cm', None, '1.57 inch', '16.00 cm', None, None, None, None, None, '73 mm']
# Batch 4624 processed, results: ['73 mm', None, None, None, None, None, '7.86 in', '7.86 in', None, '4.3 in', '4.3 in', '350 mm', '350 mm', '350 mm', '350 mm', '300 CM']
# Batch 4640 processed, results: ['8 cm', None, '43 Cm', None, None, None, None, '332 mm', '332 mm', None, None, None, None, None, None, '229 cm']
# Batch 4656 processed, results: ['229 cm', '229 cm', None, None, None, None, '163 CM', '163 CM', '0 cm', None, None, '77 in', '16 cm', '15 in', '21 g', '120 cm']
# Batch 4672 processed, results: ['120 cm', None, None, None, None, None, '70 cm', None, None, None, None, '59 cm', None, '13.8 in', '13.8 in', None]
# Batch 4688 processed, results: [None, '13 inch', '00 g', None, None, None, None, '6 cm', '6 cm', None, None, '3 cm', '3 cm', None, '18 cm', '18 cm']
# Batch 4704 processed, results: [None, None, '00 cm', '00 cm', '8.8 cm', '5 cm', None, None, None, None, None, '4.7 in', '4.7 in', '1 cm', '1 cm', None]
# Batch 4720 processed, results: ['0.39 in', '0.39 in', '28 cm', '28 cm', None, '88 in', '88 in', None, None, None, None, '1 kg', '1 kg', '36 in', None, None]
# Batch 4736 processed, results: [None, '07 in', '07 in', None, '12 inch', None, None, None, None, None, None, None, None, None, '8.66 in', None]
# Batch 4752 processed, results: [None, None, None, '3.5 cm', '3.5 cm', None, None, None, None, None, '7.8 in', None, None, None, None, None]
# Batch 4768 processed, results: [None, '24 inch', '84 cm', None, '380 Mm', None, None, None, None, None, None, None, None, None, None, None]
# Batch 4784 processed, results: [None, None, None, None, None, '1.76 in', '1.76 in', '1.76 in', '8 cm', None, '19.7 in', None, '175 kg', None, None, None]
# Batch 4800 processed, results: ['30 cm', '30 cm', '58 mm', '58 mm', None, '8.8 cm', '3 cm', '9 cm', '3.8 cm', '3.8 cm', None, '2.5 cm', '2.5 cm', '2.5 cm', '3.1 in', '3.1 in']
# Batch 4816 processed, results: [None, '1.37 inch', '1.37 inch', '28 Cm', '28 Cm', '7.08 in', '7.08 in', '7.08 in', None, '14 in', '14 in', None, None, None, None, None]
# Batch 4832 processed, results: ['30 CM', '30 CM', None, None, None, '10 cm', '10 cm', '47.9 cm', '59.6 cm', None, '13 cm', '13 cm', '1 OZ', '92 mm', '92 mm', None]
# Batch 4848 processed, results: [None, None, None, None, '72 in', '72 in', None, None, '23 cm', '23 cm', None, '27.59 Ounce', None, None, None, None]
# Batch 4864 processed, results: ['48 cm', None, None, None, None, None, None, '40 cm', None, None, '4.53 inch', None, '4 CM', '4 CM', None, None]
# Batch 4880 processed, results: [None, None, None, None, '250 lb', None, None, None, None, None, None, None, '12.7 cm', None, None, None]
# Batch 4896 processed, results: ['14 cm', '14 cm', None, '8.8 cm', '1.89 in', '1.89 in', '1.89 in', None, None, '10.3 cm', None, None, '2 INCH', '2 INCH', '2 INCH', None]
# Batch 4912 processed, results: [None, None, '84 mm', None, None, None, None, None, None, None, None, None, None, None, '500 mg', None]
# Batch 4928 processed, results: ['500 g', None, None, None, None, None, None, None, None, '8 OZ', None, '28 cm', '1.38 in', '1.38 in', None, None]
# ...
# Batch 129440 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129456 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '600 lb', '600 lb', None]
# Batch 129472 processed, results: [None, None, None, None, None, None, None, None, None, None, '1.8 kg', None, None, None, None, None]
# Batch 129488 processed, results: [None, None, None, None, None, None, None, '37 g', None, None, None, None, None, None, '0 KG', None]
# Batch 129504 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129520 processed, results: ['8.2 kg', None, None, '8 LB', None, None, None, None, None, '5 LB', None, None, None, None, None, None]
# Batch 129536 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '238 g', None, None, None]
# Batch 129552 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '200 kg', '200 kg', None]
# Batch 129568 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '220 LB', '220 LB']
# Batch 129584 processed, results: [None, None, None, None, None, '176 g', None, None, '0.3 Oz', None, None, None, None, None, None, None]
# Batch 129600 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129616 processed, results: [None, None, None, '68 kG', None, None, None, None, None, '6 kg', '6 kg', None, None, None, '310 g', None]
# Batch 129632 processed, results: [None, None, None, '2.3 OZ', None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129648 processed, results: [None, None, None, None, None, None, None, None, None, None, '3 toN', None, None, None, None, None]
# Batch 129664 processed, results: [None, None, None, '7 g', None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129680 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '1.1 pound', None, None]
# Batch 129696 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '250 g']
# Batch 129712 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '1.16 lb', '1.16 lb', None, None]
# Batch 129728 processed, results: ['22.6 kg', None, None, '20 KG', None, None, None, None, None, None, '28.55 OZ', None, None, None, None, None]
# Batch 129744 processed, results: [None, None, None, None, None, '30 Watt', None, '55 lb', None, None, None, None, None, None, None, None]
# Batch 129760 processed, results: [None, None, None, None, '280 g', None, None, None, None, None, None, None, None, None, None, '50 g']
# Batch 129776 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129792 processed, results: [None, '2 G', None, None, None, None, None, None, None, None, None, None, None, None, None, '3 kg']
# Batch 129808 processed, results: [None, None, None, None, None, None, None, None, None, '0.48 OZ', '1905 g', '250 kg', '250 kg', None, None, None]
# Batch 129824 processed, results: [None, None, None, '45 g', '0 Oz', None, None, None, None, None, None, None, None, None, None, None]
# Batch 129840 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '40 LB']
# Batch 129856 processed, results: [None, None, '150 kg', '150 kg', None, None, None, None, '4 oz', None, '120 LB', None, None, None, '82 g', '440 g']
# Batch 129872 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '3 g', None, None, None]
# Batch 129888 processed, results: [None, None, '2.51 LB', None, None, None, '113 g', None, None, None, '0.86 lb', None, None, None, None, None]
# Batch 129904 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 129920 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '1588 g', None, None]
# Batch 129936 processed, results: ['350 LB', '350 LB', None, None, None, '3 TON', None, None, None, None, None, None, None, None, None, None]
# Batch 129952 processed, results: [None, None, '5.5 LB', '5.5 LB', None, None, None, None, '8 t', None, None, None, None, None, '1.65 lb', '1.65 lb']
# Batch 129968 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '9 g', None, None, None]
# Batch 129984 processed, results: [None, None, None, None, None, None, None, '40 LB', None, None, None, None, None, None, None, None]
# Batch 130000 processed, results: [None, None, None, None, None, '1 lb', '9.88 OZ', None, None, None, None, None, '200 kg', '200 kg', None, '19.8 lb']
# Batch 130016 processed, results: ['19.8 lb', '250 kg', '250 kg', None, None, None, None, None, '1 g', None, None, None, None, None, None, None]
# Batch 130032 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '8 Oz', None, None]
# Batch 130048 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '68 KG', None]
# Batch 130064 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '45 LB', '200 LB', None]
# Batch 130080 processed, results: [None, None, None, '11.25 KG', None, '31.5 kg', None, None, None, None, '3.6 oz', None, None, None, None, None]
# Batch 130096 processed, results: ['36 kg', '36 kg', None, None, '10 kg', '10 kg', None, '133 g', None, None, None, None, None, None, None, None]
# Batch 130112 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130128 processed, results: [None, '700 g', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130144 processed, results: [None, '100 g', None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130160 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130176 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130192 processed, results: [None, None, None, None, None, None, None, None, None, None, None, '1.2 kg', '1.2 kg', '0 oz', None, None]
# Batch 130208 processed, results: [None, None, None, None, None, None, None, None, None, None, None, '11 LB', '11 LB', '65 LB', None, None]
# Batch 130224 processed, results: [None, None, None, '175 oz', None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130240 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130256 processed, results: [None, '170 g', None, '100 Watt', None, None, None, None, None, None, '13 kg', None, None, None, None, None]
# Batch 130272 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '300 g']
# Batch 130288 processed, results: [None, None, None, None, '0.12 gram', None, None, None, None, None, None, None, None, None, '2700 g', None]
# Batch 130304 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130320 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130336 processed, results: [None, None, '10 g', '10 g', None, '6.3 oz', None, None, None, None, None, None, None, None, None, None]
# Batch 130352 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130368 processed, results: [None, None, None, None, None, None, None, '7 oz', None, None, None, None, None, None, None, None]
# Batch 130384 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '300 g', None]
# Batch 130400 processed, results: [None, '175 LB', None, None, None, None, '4 T', None, '16 kg', None, None, None, '580 g', None, None, None]
# Batch 130416 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130432 processed, results: [None, None, '220 POUND', None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130448 processed, results: [None, None, None, None, None, None, '220 POUND', None, None, None, '16 LB', None, None, None, None, None]
# Batch 130464 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '2 LB', '8 g']
# Batch 130480 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '7 g']
# Batch 130496 processed, results: [None, None, None, None, None, None, None, None, '7 t', None, None, None, None, None, None, None]
# Batch 130512 processed, results: [None, None, None, None, None, '1 g', None, '13 g', None, None, None, None, None, None, None, None]
# Batch 130528 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '7.6 oz', None]
# Batch 130544 processed, results: [None, None, None, None, None, None, '23.5 g', None, None, None, None, None, None, None, None, None]
# Batch 130560 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130576 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130592 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, '0.53 OZ', None, None]
# Batch 130608 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130624 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130640 processed, results: [None, None, None, None, None, None, None, None, '12 LB', None, None, None, None, None, None, None]
# Batch 130656 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130672 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130688 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, '0.53 Oz', None, None, None]
# Batch 130704 processed, results: ['759 Quart', None, None, None, None, None, '1.4 Oz', None, None, None, None, None, None, '6 TON', '6 TON', None]
# Batch 130720 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130736 processed, results: [None, None, None, None, None, None, '643 g', None, None, None, None, None, None, '52 g', None, None]
# Batch 130752 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130768 processed, results: [None, None, None, None, None, None, '1 Gallon', None, None, None, None, None, None, None, None, None]
# Batch 130784 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130800 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130816 processed, results: [None, None, None, None, None, None, '6 oz', None, None, None, None, None, None, None, None, None]
# Batch 130832 processed, results: ['150 g', None, None, None, None, None, None, None, None, None, None, '84 g', None, None, None, None]
# Batch 130848 processed, results: ['46 KG', None, None, None, '1 LB', None, None, None, '31 kg', None, None, None, None, None, None, None]
# Batch 130864 processed, results: [None, None, '74 g', '32 oz', None, None, None, None, None, None, None, None, None, None, '300 LB', None]
# Batch 130880 processed, results: [None, None, None, None, None, None, None, None, None, None, '0.42 kg', '0.42 kg', None, '5 G', None, None]
# Batch 130896 processed, results: [None, None, None, None, None, None, '50 g', '15 LB', '2.40 LB', None, '35 oz', '40 g', None, None, None, None]
# Batch 130912 processed, results: [None, None, None, None, None, None, None, None, '4 Lb', None, None, None, None, None, None, None]
# Batch 130928 processed, results: [None, None, None, None, None, None, '4 G', '12 GRAM', None, None, '1 LB', None, None, None, None, '60 g']
# Batch 130944 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, '5 G', None]
# Batch 130960 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130976 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 130992 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131008 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131024 processed, results: [None, None, None, None, None, '1 lb', None, None, None, None, None, None, None, None, None, None]
# Batch 131040 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131056 processed, results: [None, None, None, None, None, None, None, None, None, None, None, '220 POUND', None, None, None, None]
# Batch 131072 processed, results: [None, None, None, None, '5 t', None, None, None, None, None, None, None, None, None, None, None]
# Batch 131088 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131104 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131120 processed, results: [None, None, None, None, None, None, None, None, None, None, '5.4 KG', None, None, None, None, None]
# Batch 131136 processed, results: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Batch 131152 processed, results: [None, None, None, None, None, None, None, None, None, None, '24 kg', '24 kg', None, None, None, '10 g']
# Batch 131168 processed, results: [None, None, None, None, None, '36 g', None, None, None, '88 g', None, None, None, None, '500 LB', None]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 42
#      39 entity_names = test_df["entity_name"].values[counter: counter + len(batch_images)]
#      41 # Process batch images on 8 GPUs
# ---> 42 results = process_images_on_gpus(batch_images, entity_names, num_gpus=8)
#      43 final.extend(results)
#      45 # Output results
#
# Cell In[9], line 26, in process_images_on_gpus(images, entity_names, num_gpus)
#      23     return gpu_results
#      25 with ThreadPoolExecutor(max_workers=num_gpus) as executor:
# ---> 26     futures = [executor.submit(process_on_single_gpu, images_per_gpu[gpu_id], entity_names_per_gpu[gpu_id], gpu_id)
#      27                for gpu_id in range(num_gpus)]
#      29     # Gather results
#      30     for future in futures:
#
# Cell In[9], line 26, in <listcomp>(.0)
#      23     return gpu_results
#      25 with ThreadPoolExecutor(max_workers=num_gpus) as executor:
# ---> 26     futures = [executor.submit(process_on_single_gpu, images_per_gpu[gpu_id], entity_names_per_gpu[gpu_id], gpu_id)
#      27                for gpu_id in range(num_gpus)]
#      29     # Gather results
#      30     for future in futures:
#
# IndexError: tuple index out of range

# %%
print(final)
# Out:
# [None, None, None, None, None, None, None, None, '40 cm', '40 cm', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '5.8 In', '5.8 In', '5.8 In', None, None, None, None, None, None, None, None, None, '12.5 m', '8 in', '8 in', '8 in', None, None, None, None, None, None, None, '7 cm', None, '54 m', '54 m', None, None, None, None, None, None, None, None, None, None, None, None, '23 cm', '23 cm', '23 cm', None, None, '4.7 in', '4.7 in', None, None, None, None, '11.1 lb', None, '39 in', '39 in', '39 in', None, None, None, '60 cm', '00 LB', None, None, None, '14 cm', '14 cm', None, '5 cm', '14.9 in', None, None, None, '90 cm', '40 cm', '20 cm', '20 cm', None, None, '30 cm', None, None, None, None, None, None, None, None, '3.9 in', '3.9 in', None, None, None, None, None, None, None, '129 cm', None, None, '40 cm', '25.6 in', '25.6 in', '25.6 in', None, '0 cm', '0 cm', None, '29.95 cm', '10 mm', '10 mm', '3 cm', '02 in', '02 in', '90 cm', '90 cm', '90 cm', None, None, None, None, '7495 m', '7.86 in', '7.86 in', '5 cm', '5 cm', '35 mm', None, None, None, '13 cm', None, '82 cm', None, None, None, None, '6 kG', None, None, None, None, None, '7.8 In', '7.8 In', None, None, '0.79 inch', None, '5.9 in', '5.9 in', None, '24 cm', None, None, None, '7.19 cm', '7.19 cm', '2.7 in', '2.7 in', None, '61 cm', '61 cm', None, '20 cm', '27.6 cm', '27.6 cm', None, None, None, '37.5 cm', '37.5 cm', '37.5 cm', '10 in', '10 in', None, None, '67 m', None, None, '7 mm', None, '28 cm', None, None, None, None, None, None, None, '20.6 cm', '20.6 cm', '4191 cm', None, '90 cm', '90 cm', '26 cm', None, None, None, None, '60 cm', None, None, None, None, '35 cm', '183 cm', '183 cm', '60 cm', '60 cm', '35 Cm', '7 cm', '7 cm', '4 in', '151 cm', '151 cm', '78 cm', None, '2.32 in', '2.32 in', None, None, None, None, '16 cm', '16 cm', '16 cm', None, None, None, None, '80 cm', None, None, '2.55 in', '2.55 in', '11.6 in', '20 cm', '20 cm', '2.75 in', '2.75 in', '2.75 in', None, '1.5 in', '1.5 in', None, None, None, '1.9 in', '1.9 in', '109 G', '5.8 In', '5.8 In', None, '11 cm', '68 cm', None, None, None, None, '39 cm', '39 cm', '120 kg', '4.4 in', '4.4 in', None, None, None, None, None, None, None, None, None, None, None, None, None, '0.9 in', '0.9 in', '5 cm', None, None, '21 cm', '21 cm', '21 cm', '2 CM', '2 CM', None, '2.95 in', '2.95 in', '1 m', None, None, '1 in', '1 in', '7 CM', '7 CM', '7 CM', None, None, '40 cm', '40 cm', None, None, None, '0.7 in', '0.7 in', None, None, '11 g', '25 cm', '25 cm', '25 cm', '6 m', None, None, None, None, '2.8 inch', '2.8 inch', None, None, None, '95 inch', '95 inch', '5.0 in', '5.0 in', None, '0.59 in', '0.59 in', None, None, '7 m', '35 cm', '35 cm', '35 cm', None, '60 cm', '5 cm', '5 cm', None, '4.0 cm', '4.0 cm', '57 cm', '3 kg', None, None, '4.7 In', '4.7 In', '4.7 In', '60 cm', None, None, None, None, None, None, None, None, '100 cm', '100 cm', None, None, None, None, None, None, None, None, None, None, '120 cm', '7.9 cm', '7.9 cm', None, None, None, None, None, None, '10 m', '135 mm', None, None, None, None, '2.2 In', '2.2 In', None, None, None, '27 in', '27 in', '27 in', None, '11 cm', '1.3 in', '1.3 in', '300 cm', '63 cm', '3.9 inch', '3.9 inch', '3.9 m', '3.9 m', None, None, None, '144 mm', '144 mm', None, None, None, None, None, None, None, None, '2 cm', '43 cM', None, '88 cm', '120 cm', '15.2 cm', '3.14 in', '3.14 in', '6.29 in', '6.29 in', None, None, '60 cm', '60 cm', '60 cm', None, None, None, None, None, '9 in', '9 in', None, None, None, '1 cm', None, None, None, None, None, None, None, None, '57 cm', None, None, None, '5.9 in', '5.9 in', '5.9 in', '80 cm', '80 cm', '12 mm', '12 mm', '12 mm', None, '6.37 in', '6.37 in', '25 m', '25 m', '4.8 cm', None, '12 in', '12 in', None, None, None, None, None, None, None, None, None, None, None, None, '30 cm', '30 cm', '20 Mm', None, '39.3 in', '39.3 in', '6 m', '67 cm', '3.5 in', '3.5 in', '3.5 in', ...

# %%
# save the list
np.save('final.npy',  np.array(final))
np.savetxt('final.txt', final, fmt='%s')

# %%
# convert to df
final_df = pd.DataFrame(final, columns=['entity_value'])
final_df
# Out:
#        entity_value
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 131179         None
# 131180         None
# 131181         None
# 131182       500 LB
# 131183         None
#
# [131184 rows x 1 columns]

# %%
# save the df to csv
final_df.to_csv('final.csv', index=False)
